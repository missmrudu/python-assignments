# %% [markdown]
# ## Question 1
# Assign 5 elements in the dictionary named my_dict. This dictionary contains student's
# information. Add and delete student information from my_dict. Display student
# information

# %%
#Initializing the dictionary
my_dict = { 
    "Name": "Mrudula", 
    "Age": 17, 
    "Branch": "CSE", 
    "Specialization": "AI-DS", 
    "Division": 10 
}

# %%
#Manupulating the dictionary values

my_dict["Subject"] = "Python Programming"
del my_dict["Specialization"]

# %%
#Printing the dictionary

print( my_dict.items() )
# Out:
# dict_items([('Name', 'Mrudula'), ('Age', 17), ('Branch', 'CSE'), ('Division', 10), ('Subject', 'Python Programming')])
